# %% [markdown]
# #Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# <ul>
#   <li>List popular languages for Data Science</li>
#   <li>List the most commonly used Data Science libraries</li>
#   <li>List some open source tools used for Data Science </li>
#   <li>Give examples of arithmetic expressions in Python</li>
# </ul>

# %% [markdown]
# Some of the popular languages Data Scientists use are:
# <ol>
#   <li>Python</li>
#   <li>R</li>
#   <li>SQL</li>
#   <li>SAS</li>
# </ol>

# %% [markdown]
# Some of the commonly used libraries by Data Scientists include:
# <ol>
#   <li>Pandas</li>
#   <li>NumPy</li>
#   <li>Matplotlib</li>
#   <li>Scikit-learn</li>
# </ol>

# %% [markdown]
# | Data Science Tools   |
# | -------------------- |
# | RStudio              |
# | Jupyter Notebooks    |
# | TensorFlow           |

# %% [markdown]
# ### Here are a few examples of evaluating arithmetic expressions in Python

# %%
#This is a simple arithmetic expression to multiply and add integers

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes=200
hours=minutes/60
print(round(hours))
# Out:
# 3

# %% [markdown]
# ## Author: Varga Francisca Maria
